# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/safe_turn/code"
# Out:
# /content/drive/MyDrive/Colab Notebooks/safe_turn/code

# %%
import os
from glob import glob
from tqdm import tqdm

# %%
ipynbs = glob(os.path.join('*', '*', '*.ipynb')) + glob(os.path.join('*', '*.ipynb'))

# %%
len(ipynbs)
# Out:
# 13

# %%
for ipynb in tqdm(ipynbs):
  os.system('jupyter nbconvert ' + ipynb + ' --to python')
# Out:
# 100%|██████████| 13/13 [00:16<00:00,  1.28s/it]

# %%
pys = glob(os.path.join('*', '*', '*.py')) + glob(os.path.join('*', '*.py'))

# %%
len(pys)
# Out:
# 15
